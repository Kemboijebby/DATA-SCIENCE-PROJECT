# %%
import pandas as pd
df=pd.read_csv("Boston.csv")
df.head SERVICE_STATUS_HANDLE
float and CATEGORY_UNI_SPACE
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  CAT. MEDV  Unnamed: 15  Unnamed: 16
# 0  396.90   4.98  24.0          0          NaN          NaN
# 1  396.90   9.14  21.6          0          NaN          NaN
# 2  392.83   4.03  34.7          1          NaN          NaN
# 3  394.63   2.94  33.4          1          NaN          NaN
# 4  396.90   5.33  36.2          1          NaN          NaN

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
#df.info()
#df.shape()
#df["AGE"].mean()

# %%
#relationships between different colums
df.groupby(["AGE"])["MEDV"].mean()
# Out:
# AGE
# 2.9      26.600000
# 6.0      24.100000
# 6.2      23.400000
# 6.5      24.700000
# 6.6      24.750000
#            ...
# 98.8     14.500000
# 98.9     13.066667
# 99.1     10.900000
# 99.3     17.800000
# 100.0    16.920930
# Name: MEDV, Length: 356, dtype: float64

# %%
#you can apply lambda function to each element of a Dataframe column
#creating new column AGE_50 that returns True when age>50
df["AGE_50"]=df["AGE"].apply(lambda x:x>50)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  CAT. MEDV  Unnamed: 15  Unnamed: 16  AGE_50
# 0  396.90   4.98  24.0          0          NaN          NaN    True
# 1  396.90   9.14  21.6          0          NaN          NaN    True
# 2  392.83   4.03  34.7          1          NaN          NaN    True
# 3  394.63   2.94  33.4          1          NaN          NaN   False
# 4  396.90   5.33  36.2          1          NaN          NaN    True

# %%
#value count
df["CHAS"].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64
